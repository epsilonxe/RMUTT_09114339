# %% [markdown]
# # Stock market forecasting using Time Series analysis

# %% [markdown]
# ### What is a Stock market?
#
# The stock market is a market that enables the seamless exchange of buying and selling of company stocks. Every Stock Exchange has its own Stock Index value. The index is the average value that is calculated by combining several stocks. This helps in representing the entire stock market and predicting the market’s movement over time. The stock market can have a huge impact on people and the country’s economy as a whole. Therefore, predicting the stock trends in an efficient manner can minimize the risk of loss and maximize profit.

# %% [markdown]
# ![1_xR4m0oOKz_jRgQU4Oge53g.jpeg](attachment:1_xR4m0oOKz_jRgQU4Oge53g.jpeg)

# %% [markdown]
# **Here in this notebook we will forecast the stock price of ARCH CAPITAL GROUP using ARIMA model**

# %% [markdown]
# ### What is ARIMA?
# Autoregressive Integrated Moving Average (ARIMA) Model converts non-stationary data to stationary data before working on it. It is one of the most popular models to predict linear time series data.
#
#
# ARIMA model has been used extensively in the field of finance and economics as it is known to be robust, efficient and has a strong potential for short-term share market prediction.

# %% [markdown]
# ### Load all the required libraries

# %%
import os
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# plt.style.use('fivethirtyeight')
from pylab import rcParams
rcParams['figure.figsize'] = 10, 6
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima.model import ARIMA
from pmdarima.arima import auto_arima

from sklearn.metrics import mean_squared_error, mean_absolute_error
import math
# Out:
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/mson.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/fftg.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ds.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/sbi.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ca.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/brc.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/any.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/fwp.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/aegn.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/spmd.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/bgi.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/mhk.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cibr.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/iret.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/tex.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/irt.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/vta.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/reis.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/hbm.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/rcii.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/arql.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/dlr_c.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/isf.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/tpx.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/iin.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ds_b.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/tco.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/clmt.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/apdnw.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/hk-ws.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/attu.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/mdp.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/chke.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/alfi.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ngl_b.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/schw_c.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/djco.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/infr.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/srci.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/bsjo.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/smhd.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/agm_a.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/aqua.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/alna.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/qcp.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/stkl.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/bmo.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ivlu.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/tpgh-ws.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/enia.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/aaxn.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/bdxa.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cyou.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/sce_h.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/omaa.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/jta.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/gst_b.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/semg.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/sybt.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/gyro.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/msft.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/alty.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/bv.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/kbwy.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/afsi_b.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/opp.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cix.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/gcvrz.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/flco.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/aosl.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/tannz.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/wbib.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cslt.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cpk.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cmi.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/now.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/divy.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ppx.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/strm.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/hgh.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/vly_b.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/hbcp.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/bfy.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/lvntb.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/vnrx.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/pnf.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/brx.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/znh.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/vrs.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cpl.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/bll.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cof_g.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/dlr_i.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/faf.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/vnce.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/pref.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/hmnf.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/bnso.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/gmed.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/wbbw.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/hql.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ifn.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/abco.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/pbib.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/sb.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/csu.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/gjv.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/asys.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/lpsn.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/wifi.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/nflt.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/wvvi.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/xgti.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/amrh.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cece.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/gvp.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/snbr.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/tdf.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ohgi.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/rmgn.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/rndv.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/sail.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/exg.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/jpm_a.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/avp.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/quot.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/casc.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/grx.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/fsp.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/mp_d.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/upld.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/pfpt.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/jls.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/pgz.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/pbr.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/bcacr.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/smplw.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/tacow.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/usph.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/star_f.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/eto.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/casi.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cat.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/tlnd.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/abtx.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/manh.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/mtfbw.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/arh_c.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ebay.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/vtr.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/brac.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/vrnt.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/kcapl.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/wstl.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/hiho.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/jmp.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/fsnn.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/plab.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/redu.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/npn.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/pbct.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/tif.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cuda.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/clx.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/kar.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/isze.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/kgji.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ten.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/true.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/sq.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/grf.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cbo.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/xone.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/bemo.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/kt.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/jrjr.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/loxo.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/pay.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/pmts.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/sum.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/usap.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/fedu.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/brks.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/pmt_a.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/pslv.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ttwo.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/kst.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cic-ws.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/sgh.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/mmlp.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/snv.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/mynd.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/tgls.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cnxn.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/el.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/all_a.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/asmb.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/gpc.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/mtdr.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ldl.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/spxv.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/taco.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks
.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/gcc.us.txt

# %%
stock_data = pd.read_csv('acgl.us.txt', sep=',').fillna(0)
stock_data
# Out:
#             Date    Open    High     Low   Close  Volume  OpenInt
# 0     2005-02-25  13.583  13.693  13.430  13.693  156240        0
# 1     2005-02-28  13.697  13.827  13.540  13.827  370509        0
# 2     2005-03-01  13.780  13.913  13.720  13.760  224484        0
# 3     2005-03-02  13.717  13.823  13.667  13.810  286431        0
# 4     2005-03-03  13.783  13.783  13.587  13.630  193824        0
# ...          ...     ...     ...     ...     ...     ...      ...
# 3196  2017-11-06  94.490  95.650  94.020  95.550  420192        0
# 3197  2017-11-07  95.860  95.950  95.200  95.560  464011        0
# 3198  2017-11-08  95.410  95.900  94.890  95.450  471756        0
# 3199  2017-11-09  94.930  96.140  94.470  95.910  353498        0
# 3200  2017-11-10  95.890  95.990  94.390  95.350  452833        0
#
# [3201 rows x 7 columns]

# %%
stock_data.Date = pd.to_datetime(stock_data.Date, format='%Y-%m-%d')

# %%
stock_data = stock_data.set_index('Date')

# %%
stock_data
# Out:
#               Open    High     Low   Close  Volume  OpenInt
# Date
# 2005-02-25  13.583  13.693  13.430  13.693  156240        0
# 2005-02-28  13.697  13.827  13.540  13.827  370509        0
# 2005-03-01  13.780  13.913  13.720  13.760  224484        0
# 2005-03-02  13.717  13.823  13.667  13.810  286431        0
# 2005-03-03  13.783  13.783  13.587  13.630  193824        0
# ...            ...     ...     ...     ...     ...      ...
# 2017-11-06  94.490  95.650  94.020  95.550  420192        0
# 2017-11-07  95.860  95.950  95.200  95.560  464011        0
# 2017-11-08  95.410  95.900  94.890  95.450  471756        0
# 2017-11-09  94.930  96.140  94.470  95.910  353498        0
# 2017-11-10  95.890  95.990  94.390  95.350  452833        0
#
# [3201 rows x 6 columns]

# %% [markdown]
# Visualize the per day closing price of the stock.

# %%
#plot close price
plt.figure(figsize=(10,6))
plt.grid(True)
plt.xlabel('Date')
plt.ylabel('Close Prices')
plt.plot(stock_data['Close'])
plt.title('ARCH CAPITAL GROUP closing price')
plt.show()

# %% [markdown]
# ### We can also visualize the data in our series through a probability distribution too.

# %%
#Distribution of the dataset
stock_data['Close'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# Also, a given time series is thought to consist of three systematic components including level, trend, seasonality, and one non-systematic component called noise.
#
# These components are defined as follows:
#
# 1. **Level**: The average value in the series.
#
# 2. **Trend**: The increasing or decreasing value in the series.
#
# 3. **Seasonality**: The repeating short-term cycle in the series.
#
# 4. **Noise**: The random variation in the series.
#
# First, we need to check if a series is stationary or not because time series analysis only works with stationary data.
#
#
# **ADF (Augmented Dickey-Fuller) Test**
#
# The Dickey-Fuller test is one of the most popular statistical tests. It can be used to determine the presence of unit root in the series, and hence help us understand if the series is stationary or not. The null and alternate hypothesis of this test is:
#
#
# **Null Hypothesis**: The series has a unit root (value of a =1)
#
#
# **Alternate Hypothesis**: The series has no unit root.
#
#
# If we fail to reject the null hypothesis, we can say that the series is non-stationary. This means that the series can be linear or difference stationary.
#
#
# If both mean and standard deviation are flat lines(constant mean and constant variance), the series becomes stationary.
#
#
# **So let's check for stationarity:

# %%
#Test for staionarity
def test_stationarity(timeseries):
    #Determing rolling statistics
    rolmean = timeseries.rolling(12).mean()
    rolstd = timeseries.rolling(12).std()
    #Plot rolling statistics:
    plt.plot(timeseries, color='blue',label='Original')
    plt.plot(rolmean, color='red', label='Rolling Mean')
    plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean and Standard Deviation')
    plt.show(block=False)
    
    print("Results of dickey fuller test")
    adft = adfuller(timeseries,autolag='AIC')
    # output for dft will give us without defining what the values are.
    #hence we manually write what values does it explains using a for loop
    output = pd.Series(adft[0:4],index=['Test Statistics','p-value','No. of lags used','Number of observations used'])
    for key,values in adft[4].items():
        output['critical value (%s)'%key] =  values
    print(output)
    
test_stationarity(stock_data['Close'])
# Out:
# Results of dickey fuller test
# Test Statistics                   1.374899
# p-value                           0.996997
# No. of lags used                  5.000000
# Number of observations used    3195.000000
# critical value (1%)              -3.432398
# critical value (5%)              -2.862445
# critical value (10%)             -2.567252
# dtype: float64

# %% [markdown]
# Through the above graph, we can see the increasing mean and standard deviation and hence our series is not stationary.

# %% [markdown]
# We start by taking a log of the series to reduce the magnitude of the values and reduce the rising trend in the series. Then after getting the log of the series, we find the rolling average of the series. A rolling average is calculated by taking input for the past 12 months and giving a mean consumption value at every point further ahead in series.

# %%
#if not stationary then eliminate trend
#Eliminate trend
from pylab import rcParams
rcParams['figure.figsize'] = 10, 6
df_log = np.log(stock_data['Close'])
moving_avg = df_log.rolling(12).mean()
std_dev = df_log.rolling(12).std()
plt.legend(loc='best')
plt.title('Moving Average')
plt.plot(std_dev, color ="black", label = "Standard Deviation")
plt.plot(moving_avg, color="red", label = "Mean")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Now we are going to create an ARIMA model and will train it with the closing price of the stock on the train data. So let us split the data into training and test set and visualize it.

# %%
#split data into train and training set
train_data, test_data = df_log[3:int(len(df_log)*0.9)], df_log[int(len(df_log)*0.9):]
plt.figure(figsize=(10,6))
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Closing Prices')
plt.plot(df_log, 'green', label='Train data')
plt.plot(test_data, 'blue', label='Test data')
plt.legend()

# %% [markdown]
# Its time to choose parameters p,q,d for ARIMA model. Last time we chose the value of p,d, and q by observing the plots of ACF and PACF but now we are going to use Auto ARIMA to get the best parameters without even plotting ACF and PACF graphs.

# %% [markdown]
# #### Auto ARIMA: Automatically discover the optimal order for an ARIMA model.
#
#
# The auto_arima function seeks to identify the most optimal parameters for an ARIMA model, and returns a fitted ARIMA model. This function is based on the commonly-used R function, **forecast::auto.arima**.
#
#
# The **auro_arima** function works by conducting differencing tests (i.e., **Kwiatkowski–Phillips–Schmidt–Shin, Augmented Dickey-Fuller or Phillips–Perron**) to determine the order of differencing, d, and then fitting models within ranges of defined start_p, max_p, start_q, max_q ranges. If the seasonal optional is enabled, auto_arima also seeks to identify the optimal P and Q hyper- parameters after conducting the **Canova-Hansen** to determine the optimal order of seasonal differencing, D.

# %%
model_autoARIMA = auto_arima(train_data, start_p=0, start_q=0,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=3, max_q=3, # maximum p and q
                      m=1,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)
print(model_autoARIMA.summary())
model_autoARIMA.plot_diagnostics(figsize=(15,8))
plt.show()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-16491.508, Time=0.17 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-16525.992, Time=0.12 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-16527.964, Time=0.16 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-16488.323, Time=0.05 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-16527.157, Time=0.27 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=-16527.120, Time=0.55 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=-16528.810, Time=0.75 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.83 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=-16526.020, Time=0.80 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=-16524.974, Time=0.52 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=-16525.435, Time=0.40 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=-16516.417, Time=0.41 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=-16527.597, Time=0.40 sec
#
# Best model:  ARIMA(1,1,2)(0,0,0)[0] intercept
# Total fit time: 5.481 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 2877
# Model:               SARIMAX(1, 1, 2)   Log Likelihood                8269.405
# Date:                Thu, 14 Mar 2024   AIC                         -16528.810
# Time:                        00:24:41   BIC                         -16498.989
# Sample:                             0   HQIC                        -16518.061
#                                - 2877
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   2.467e-05   7.12e-06      3.464      0.001    1.07e-05    3.86e-05
# ar.L1          0.9538      0.009    104.140      0.000       0.936       0.972
# ma.L1         -1.0708      0.015    -73.566      0.000      -1.099      -1.042
# ma.L2          0.0877      0.012      7.504      0.000       0.065       0.111
# sigma2         0.0002   2.32e-06     80.805      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              7207.33
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.30   Skew:                            -0.39
# Prob(H) (two-sided):                  0.00   Kurtosis:                        10.72
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# So how to interpret the plot diagnostics?
#
#
# **Top left**: The residual errors seem to fluctuate around a mean of zero and have a uniform variance.
#
#
# **Top Right**: The density plot suggest normal distribution with mean zero.
#
#
# **Bottom left**: All the dots should fall perfectly in line with the red line. Any significant deviations would imply the distribution is skewed.
#
#
# **Bottom Right**: The Correlogram, aka, ACF plot shows the residual errors are not autocorrelated. Any autocorrelation would imply that there is some pattern in the residual errors which are not explained in the model. So you will need to look for more X’s (predictors) to the model.
#
#
# Overall, it seems to be a good fit. Let’s start forecasting the stock prices.
#
#
# Next, create an ARIMA model with provided optimal parameters p, d and q.

# %% [markdown]
# **So the Auto ARIMA model provided the value of p,d, and q as 1, 1 and 2 respectively.**

# %%
train_data = train_data.sort_index()

# %%
# Modeling
# Build Model
model = ARIMA(train_data, order=(1,1,2))  
fitted = model.fit()  
print(fitted.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                 2877
# Model:                 ARIMA(1, 1, 2)   Log Likelihood                8267.798
# Date:                Thu, 14 Mar 2024   AIC                         -16527.597
# Time:                        00:30:55   BIC                         -16503.740
# Sample:                    03-02-2005   HQIC                        -16518.997
#                          - 08-04-2016
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8973      0.036     24.798      0.000       0.826       0.968
# ma.L1         -1.0130      0.039    -25.731      0.000      -1.090      -0.936
# ma.L2          0.0826      0.014      5.842      0.000       0.055       0.110
# sigma2         0.0002   2.29e-06     81.316      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.07   Jarque-Bera (JB):              7150.64
# Prob(Q):                              0.80   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.30   Skew:                            -0.23
# Prob(H) (two-sided):                  0.00   Kurtosis:                        10.71
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ### Now let's start forecast the stock prices on the test dataset keeping 95% confidence level.

# %%
# Forecast
fc = fitted.forecast(321, alpha=0.05)  # 95% conf

# %% [markdown]
# Plot the results

# %%
# Make as pandas series
fc_series = pd.Series(list(fc), index=test_data.index)
# lower_series = pd.Series(conf[:, 0], index=test_data.index)
# upper_series = pd.Series(conf[:, 1], index=test_data.index)
# Plot
plt.figure(figsize=(10,5), dpi=100)
plt.plot(train_data, label='training data')
plt.plot(test_data, color = 'blue', label='Actual Stock Price')
plt.plot(fc_series, color = 'orange',label='Predicted Stock Price')
# plt.fill_between(lower_series.index, lower_series, upper_series, 
                 # color='k', alpha=.10)
plt.title('ARCH CAPITAL GROUP Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('ARCH CAPITAL GROUP Stock Price')
plt.legend(loc='upper left', fontsize=8)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 7
#       3 # lower_series = pd.Series(conf[:, 0], index=test_data.index)
#       4 # upper_series = pd.Series(conf[:, 1], index=test_data.index)
#       5 # Plot
#       6 plt.figure(figsize=(10,5), dpi=100)
# ----> 7 plt.plot(train_data, label='training data')
#       8 plt.plot(test_data, color = 'blue', label='Actual Stock Price')
#       9 plt.plot(fc_series, color = 'orange',label='Predicted Stock Price')
#
# File ~/.pyenv/versions/3.10.6/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/pyplot.py:3578, in plot(scalex, scaley, data, *args, **kwargs)
#    3570 @_copy_docstring_and_deprecators(Axes.plot)
#    3571 def plot(
#    3572     *args: float | ArrayLike | str,
#    (...)
#    3576     **kwargs,
#    3577 ) -> list[Line2D]:
# -> 3578     return gca().plot(
#    3579         *args,
#    3580         scalex=scalex,
#    3581         scaley=scaley,
#    3582         **({"data": data} if data is not None else {}),
#    3583         **kwargs,
#    3584     )
#
# File ~/.pyenv/versions/3.10.6/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axes/_axes.py:1723, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1721 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1722 for line in lines:
# -> 1723     self.add_line(line)
#    1724 if scalex:
#    1725     self._request_autoscale_view("x")
#
# File ~/.pyenv/versions/3.10.6/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axes/_base.py:2309, in _AxesBase.add_line(self, line)
#    2306 if line.get_clip_path() is None:
#    2307     line.set_clip_path(self.patch)
# -> 2309 self._update_line_limits(line)
#    2310 if not line.get_label():
#    2311     line.set_label(f'_child{len(self._children)}')
#
# File ~/.pyenv/versions/3.10.6/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axes/_base.py:2332, in _AxesBase._update_line_limits(self, line)
#    2328 def _update_line_limits(self, line):
#    2329     """
#    2330     Figures out the data limit of the given line, updating self.dataLim.
#    2331     """
# -> 2332     path = line.get_path()
#    2333     if path.vertices.size == 0:
#    2334         return
#
# File ~/.pyenv/versions/3.10.6/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/lines.py:1032, in Line2D.get_path(self)
#    1030 """Return the `~matplotlib.path.Path` associated with this line."""
#    1031 if self._invalidy or self._invalidx:
# -> 1032     self.recache()
#    1033 return self._path
#
# File ~/.pyenv/versions/3.10.6/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/lines.py:669, in Line2D.recache(self, always)
#     667 if always or self._invalidx:
#     668     xconv = self.convert_xunits(self._xorig)
# --> 669     x = _to_unmasked_float_array(xconv).ravel()
#     670 else:
#     671     x = self._x
#
# File ~/.pyenv/versions/3.10.6/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/cbook.py:1345, in _to_unmasked_float_array(x)
#    1343     return np.ma.asarray(x, float).filled(np.nan)
#    1344 else:
# -> 1345     return np.asarray(x, float)
#
# TypeError: float() argument must be a string or a real number, not 'Period'

# %% [markdown]
# As you can see our model did quite handsomely. Let us also check the commonly used accuracy metrics to judge forecast results:

# %%
# report performance
mse = mean_squared_error(test_data, fc)
print('MSE: '+str(mse))
mae = mean_absolute_error(test_data, fc)
print('MAE: '+str(mae))
rmse = math.sqrt(mean_squared_error(test_data, fc))
print('RMSE: '+str(rmse))
mape = np.mean(np.abs(fc - test_data)/np.abs(test_data))
print('MAPE: '+str(mape))
# Out:
# MSE: 0.0504716404349648
# MAE: 0.20771790107420013
# RMSE: 0.22465894247717982
# MAPE: nan

# %% [markdown]
# ### Around 2.5% MAPE implies the model is about 97.5% accurate in predicting the next 15 observations.
